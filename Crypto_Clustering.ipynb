# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
# df_market_data.columns
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
df_market_data_scaled = StandardScaler().fit_transform(df_market_data[['price_change_percentage_24h', 'price_change_percentage_7d',\
       'price_change_percentage_14d', 'price_change_percentage_30d',\
       'price_change_percentage_60d', 'price_change_percentage_200d',\
       'price_change_percentage_1y']])

df_market_data_scaled[:5]
# Out:
# array([[ 0.50852937,  0.49319307,  0.77220043,  0.23545963, -0.0674951 ,
#         -0.35595348, -0.25163688],
#        [ 0.18544589,  0.93444504,  0.55869212, -0.05434093, -0.27348273,
#         -0.11575947, -0.19935211],
#        [ 0.02177396, -0.70633685, -0.02168042, -0.06103015,  0.00800452,
#         -0.55024692, -0.28206051],
#        [-0.04076438, -0.81092807,  0.24945797, -0.05038797, -0.37316402,
#         -0.45825882, -0.29554614],
#        [ 1.19303608,  2.00095907,  1.76061001,  0.54584206, -0.29120287,
#         -0.49984776, -0.27031695]])

# %%
# Create a DataFrame with the scaled data
df_market_data_norm = pd.DataFrame(df_market_data_scaled,columns =['price_change_percentage_24h', 'price_change_percentage_7d',\
       'price_change_percentage_14d', 'price_change_percentage_30d',\
       'price_change_percentage_60d', 'price_change_percentage_200d',\
       'price_change_percentage_1y'] )

# Copy the crypto names from the original data
df_market_data_norm["coin_id"] = df_market_data.index
# Set the coinid column as index
df_market_data_norm=df_market_data_norm.set_index("coin_id")

# Display sample data
df_market_data_norm.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Data.

# %%
# Create a list with the number of k-values from 1 to 11
k = list(range(1,11))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_scaled`
# 3. Append the model.inertia_ to the inertia list

for i in k:
    model = KMeans(n_clusters=i, random_state=42)
    model.fit(df_market_data_norm)
    inertia.append(model.inertia_)
# Out:
# /Users/snehathomas/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/snehathomas/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/snehathomas/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow={"k":k,"inertia":inertia}

# Create a DataFrame with the data to plot the Elbow curve
elbow_df=pd.DataFrame(elbow)
elbow_df
# Out:
#     k     inertia
# 0   1  287.000000
# 1   2  195.820218
# 2   3  123.190482
# 3   4   79.022435
# 4   5   65.220364
# 5   6   52.829819
# 6   7   43.786435
# 7   8   37.527740
# 8   9   33.070926
# 9  10   28.989073

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
elbow_df.hvplot.line(
    x="k", 
    y="inertia", 
    title="Elbow Curve", 
    xticks=k
)
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** At 4 clusters the inertia value does not drop much further and hits saturation.

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Data

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters=4,random_state=42)

# %%
# Fit the K-Means model using the scaled data
model.fit(df_market_data_norm)
# Out:
# /Users/snehathomas/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
# Create a copy of the DataFrame
# Predict the clusters to group the cryptocurrencies using the scaled data
df_market_data_clusters = df_market_data_norm.copy()
# Add a new column to the DataFrame with the predicted clusters
df_market_data_clusters["cluster_prediction"]=model.predict(df_market_data_norm)

# Print the resulting array of cluster values.
# Display sample data
df_market_data_clusters
# Out:
#                       price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                                  0.508529                    0.493193
# ethereum                                 0.185446                    0.934445
# tether                                   0.021774                   -0.706337
# ripple                                  -0.040764                   -0.810928
# bitcoin-cash                             1.193036                    2.000959
# binancecoin                              0.891871                    1.327295
# chainlink                                0.011397                    2.572251
# cardano                                  0.102530                    1.508001
# litecoin                                 0.077497                    0.334297
# bitcoin-cash-sv                          0.448952                   -0.190684
# crypto-com-chain                         0.331280                   -1.614844
# ...

# %%
# Create a scatter plot using hvPlot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
df_market_data_clusters.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by="cluster_prediction",
    hover_cols = ["coin_id"], 
    title = "Scatter Plot by Coin Segment"
)
# Out:
# :NdOverlay   [cluster_prediction]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce to three principal components.
market_data_pca = pca.fit_transform(df_market_data_norm)
# View the first five rows of the DataFrame. 
market_data_pca[:5]
# Out:
# array([[-0.60066733,  0.84276006,  0.46159457],
#        [-0.45826071,  0.45846566,  0.95287678],
#        [-0.43306981, -0.16812638, -0.64175193],
#        [-0.47183495, -0.22266008, -0.47905316],
#        [-1.15779997,  2.04120919,  1.85971527]])

# %%
# Retrieve the explained variance to determine how much information can be attributed to each principal component.
pca.explained_variance_ratio_
# Out:
# array([0.3719856 , 0.34700813, 0.17603793])

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** The 3 pricipal components explains 89.5% of all variables - in this case it is split 37.2% , 34.7% and 17.6% across the 3 PCs

# %%
# Create a new DataFrame with the PCA data.
df_market_data_pca = pd.DataFrame(market_data_pca,columns=["PC1","PC2","PC3"])
# Creating a DataFrame with the PCA data

# Copy the crypto names from the original data
df_market_data_pca["coin_id"] = df_market_data.index

# Set the coinid column as index
df_market_data_pca = df_market_data_pca.set_index("coin_id")

# Display sample data
df_market_data_pca.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values from 1 to 11
k = list(range(1,11))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_pca`
# 3. Append the model.inertia_ to the inertia list
for i in k:
    model = KMeans(n_clusters=i, random_state=42)
    model.fit(df_market_data_pca)
    inertia.append(model.inertia_)
# Out:
# /Users/snehathomas/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/snehathomas/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/snehathomas/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_p={"k":k,"inertia_p":inertia}

# Create a DataFrame with the data to plot the Elbow curve
elbow_df_p=pd.DataFrame(elbow_p)
elbow_df_p
# Out:
#     k   inertia_p
# 0   1  256.874086
# 1   2  168.811896
# 2   3   93.774626
# 3   4   49.665497
# 4   5   37.878747
# 5   6   27.618972
# 6   7   21.182776
# 7   8   17.091637
# 8   9   13.667065
# 9  10   10.559358

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
elbow_df_p.hvplot.line(
    x="k", 
    y="inertia_p", 
    title="Elbow Curve", 
    xticks=k
)
# Out:
# :Curve   [k]   (inertia_p)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** The best value for k is still 4 after PCA
#
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** No the vaue of k stays the same

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters=4,random_state=42)

# %%
# Fit the K-Means model using the PCA data
model.fit(df_market_data_pca)
# Out:
# /Users/snehathomas/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
# Create a copy of the DataFrame with the PCA data
# Predict the clusters to group the cryptocurrencies using the PCA data
df_market_data_pca_clusters = df_market_data_pca.copy()
# Add a new column to the DataFrame with the predicted clusters
df_market_data_pca_clusters["cluster_prediction_p"]=model.predict(df_market_data_pca)

# Print the resulting array of cluster values.
# Display sample data
df_market_data_pca_clusters
# Out:
#                            PC1       PC2       PC3  cluster_prediction_p
# coin_id
# bitcoin              -0.600667  0.842760  0.461595                     3
# ethereum             -0.458261  0.458466  0.952877                     3
# tether               -0.433070 -0.168126 -0.641752                     0
# ripple               -0.471835 -0.222660 -0.479053                     0
# bitcoin-cash         -1.157800  2.041209  1.859715                     3
# binancecoin          -0.516534  1.388377  0.804071                     3
# chainlink            -0.450711  0.517699  2.846143                     3
# cardano              -0.345600  0.729439  1.478013                     3
# litecoin             -0.649468  0.432165  0.600303                     3
# bitcoin-cash-sv      -0.759014 -0.201200 -0.217653                     0
# crypto-com-chain     -0.248198 -1.376252 -1.462026                     0
# usd-coin             -0.438408 -0.175337 -0.663388                     0
# ...

# %%
# Create a scatter plot using hvPlot by setting 
# `x="PC1"` and `y="PC2"`. 
# Color the graph points with the labels found using K-Means and add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
df_market_data_pca_clusters.hvplot.scatter(
    x="PC1",
    y="PC2",
    by="cluster_prediction_p",
    hover_cols = ["coin_id"], 
    title = "Scatter Plot by Coin Segment (PCA)"
)
# Out:
# :NdOverlay   [cluster_prediction_p]
#    :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves
# Did not use the + method for the elbow curves since this was more intuitive to compare. Did however use it for the scatter plots that cannot have the same axes.
elbow_composite_df = pd.merge(elbow_df,elbow_df_p, how ="inner", on = "k")
elbow_composite_df.hvplot.line(
    x="k", 
    y=["inertia","inertia_p"], 
    title="Elbow Curve Comparison", 
    xticks=k
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [k]   (value)

# %%
# Composite plot to contrast the clusters

Original_scatter_plot = df_market_data_clusters.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by="cluster_prediction",
    hover_cols = ["coin_id"], 
    title = "Scatter Plot by Coin Segment"
)
PCA_scatter_plot = df_market_data_pca_clusters.hvplot.scatter(
    x="PC1",
    y="PC2",
    by="cluster_prediction_p",
    hover_cols = ["coin_id"], 
    title = "Scatter Plot by Coin Segment (PCA)"
)

(Original_scatter_plot + PCA_scatter_plot).cols(1)
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [cluster_prediction]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [cluster_prediction_p]
#       :Scatter   [PC1]   (PC2,coin_id)

# %%
# Create a dataframe to understand the weights assigned to each variable for each principal component
feature_weights_df = pd.DataFrame(pca.components_, 
                                  columns=df_market_data_norm.columns, 
                                  index=['PCA' + str(i+1) for i in range(len(pca.components_))])

# Display the DataFrame
feature_weights_df
# Out:
#       price_change_percentage_24h  price_change_percentage_7d  \
# PCA1                    -0.416728                   -0.102432
# PCA2                     0.358162                    0.227432
# PCA3                    -0.218795                    0.787670
#
#       price_change_percentage_14d  price_change_percentage_30d  \
# PCA1                    -0.009162                     0.191523
# PCA2                     0.540415                     0.562182
# PCA3                     0.349534                    -0.181744
#
#       price_change_percentage_60d  price_change_percentage_200d  \
# PCA1                     0.320365                      0.594468
# PCA2                     0.434040                      0.027735
# PCA3                    -0.361377                      0.039733
#
#       price_change_percentage_1y
# PCA1                    0.568379
# PCA2                   -0.150789
# PCA3                    0.210541

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** The PCA allows us to explain most of the crptocurrencies with just two variables and is hence more efficient. It clearly shows two CCs 'ethlend' and 'cesius-degree-token' that lie in seperate clusters since they are on opposite ends of the values for PC2 and PC3
